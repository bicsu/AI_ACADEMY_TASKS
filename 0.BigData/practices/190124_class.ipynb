# %%
import numpy as np
from scipy import stats
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.proportion import proportions_ztest

# %%
np.random.seed(seed=1234)

# %%
normal = np.random.normal(20,2,100000)

# %%
sns.distplot(normal, fit=stats.norm, kde=True)

# %%
sns.distplot(normal, fit=stats.norm, kde=False)

# %%
Xbar = 30
std = 2.5
normal = np.random.normal(Xbar, std, 100000)
sns.distplot(normal, fit=stats.norm, kde = True)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
mu = 115
sigma = 20
x = 135
prop = stats.norm.cdf(x, mu, sigma)
print("{0}분 이상 걸리는 A/S 작업 비율: {1:.1f}%".format(x, (1-prop)*100))
# Out:
# 135분 이상 걸리는 A/S 작업 비율: 15.9%

# %%
mu = 12
s = 3
x = 12
prop = stats.norm.cdf(x, mu, s)
print("{0}: {1:.4f}%".format(x, (1-prop)*100))
# Out:
# 12: 50.000%

# %%
mu = 175
s = 5
x = 190
prop = stats.norm.cdf(x, mu, s)
print("{0}: {1:.5f}%".format(x, (1-prop)*100))
# Out:
# 190: 0.13499%

# %%
99.9-65.5
# Out:
# 34.400000000000006

# %% [markdown]
# # 숙제1

# %%
# 1)
mu = 12
s = 3
x = 12
x_a = 15
prop = stats.norm.cdf(x, mu, s)
prop_a = stats.norm.cdf(x_a, mu, s)
print("{0}km 이상 {1}km 이하: {2:.3f}%".format(x,x_a,(1-prop)*100-(1-prop_a)*100))
# Out:
# 0.5
# 0.8413447460685429
# 12km 이상 15km 이하: 34.134%

# %%
# 2)
mu = 12
s = 3
x = 9
x_a = 15
prop = stats.norm.cdf(x, mu, s)
prop_a = stats.norm.cdf(x_a, mu, s)
print("{0}km 이상 {1}km 이하: {2:.3f}%".format(x, x_a, (1-prop)*100-(1-prop_a)*100))
# Out:
# 0.15865525393145707
# 0.8413447460685429
# 9km 이상 15km 이하: 68.269%

# %%
# 3) 15km 이상 확률
mu = 12
s = 3
x = 15
prop = stats.norm.cdf(x, mu, s)
print("{0}km 이상일 확률 : {1:.3f}%".format(x, (1-prop)*100))
# Out:
# 15km 이상일 확률 : 15.866%

# %% [markdown]
# # p16

# %%
np.random.seed(seed = 1234)
normal = np.random.normal(0,1,10000)
sns.distplot(normal)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
normal.round(3)
# Out:
# array([ 0.471, -1.191,  1.433, ..., -1.052, -0.498, -0.256])

# %% [markdown]
# # p18

# %%
np.random.seed(seed = 1234)
t_df29 = np.random.standard_t(df=29, size = 1000)
sns.distplot(t_df29, fit = stats.norm, kde=True)

# %%
np.random.seed(seed = 1234)
t_df29 = np.random.standard_t(df=10, size = 1000)
sns.distplot(t_df29, fit = stats.norm, kde=True)

# %%
np.random.seed(seed = 1234)
t_df29 = np.random.standard_t(df=50, size = 1000)
sns.distplot(t_df29, fit = stats.norm, kde=True)

# %% [markdown]
# # p19

# %%
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(2, 1, 1)
plt.gca().set_title('df50')
ax2 = fig.add_subplot(2, 1, 2)
plt.gca().set_title('df200')
np.random.seed(seed = 1234)
t_df29 = np.random.standard_t(df=50, size = 10000)
sns.distplot(t_df29, fit = stats.norm, kde=True, ax=ax1)
np.random.seed(seed = 1234)
t_df200 = np.random.standard_t(df=200, size = 10000)
sns.distplot(t_df200, fit = stats.norm, kde=True, ax = ax2)

# %% [markdown]
# p 20

# %%
t = 1.53
df = 5
prop = stats.t.cdf(t, df)
print("P(T<={0}) : {1:.3f}".format(t, prop))
# Out:
# P(T<=1.53) : 0.907

# %% [markdown]
# # 숙제2

# %%
t = 2
df = 10
t_a = 1
prop = stats.t.cdf(t, df)
prop_a = stats.t.cdf(t_a, df)
print("P(1<=T<=2) : {1:.3f}".format(t-t_a, prop-prop_a))
# Out:
# P(1<=T<=2) : 0.134

# %% [markdown]
# # P 22

# %%
np.random.seed(seed=1234)
chisq_df10 = np.random.chisquare(df = 10, size = 1000)
sns.distplot(chisq_df10, kde = True)
chisq_df20 = np.random.chisquare(df = 30, size = 1000)
sns.distplot(chisq_df20, kde = True)

# %% [markdown]
# # P24

# %%
chisq = 10
df = 3
#누적확률 값 계산
prop = stats.chi2.cdf(chisq, df)
print("P(X<={0}) :{1:.4f}".format(chisq, prop))
# sns.distplot(prop)
# Out:
# P(X<=10) :0.9814

# %% [markdown]
# # P 25

# %%
chisq = 3
df = 8
#누적확률 값 계산
prop = stats.chi2.cdf(chisq, df)
print("P(X<={0}) :{1:.4f}".format(chisq, prop))
# sns.distplot(prop)
# Out:
# P(X<=3) :0.0656

# %% [markdown]
# # P 26

# %%
np.random.seed(seed = 1234)
#분자 자유도 : 10, 분모 자유도: 10
# 데이터 수 : 1000개의 F분포를 따르는 데이터 생성

F_df10_10 = np.random.f(dfnum=10, dfden=10, size=1000)

sns.distplot(F_df10_10, kde=True)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # P 27

# %%
plt.figure(figsize=(9,9))
F_df10_10 = np.random.f(dfnum=10, dfden=10, size=1000)
sns.distplot(F_df10_10, kde=True)
F_df10_50 = np.random.f(dfnum=10, dfden=50, size=100)
sns.distplot(F_df10_50, kde=True)

# %% [markdown]
# # p29

# %%
x = 1500
alpha = 2.2
beta = 1200
#누적확률 값 계산
prop = stats.weibull_min.cdf(x, alpha, scale = beta)
print("P(X>={0}): {1:.5f}".format(x, (1-prop)))
# Out:
# P(X>=1500): 0.19518

# %% [markdown]
# # P 34

# %%
# 도장공정에서 광택도 불량이 40%나 된다고 함
# 3대의 차량을 임의로 선택했을 때 불량대수가 각각 0,1,2,3대가 나올 확률
n = 10
for i in range(4):
    # 이항분포 Probability Mass Function
    prop = stats.binom.pmf(k=i, n=n, p=0.4)
    print("(X={0}) = {1:.3f}".format(i, prop))
# Out:
# (X=0) = 0.006
# (X=1) = 0.040
# (X=2) = 0.121
# (X=3) = 0.215

# %% [markdown]
# # p35

# %%
# 도장공정에서 광택도 불량이 30%나 된다고 함
# 5대의 차량을 임의로 선택했을 때 불량대수가 각각 0,1,2,3,4,5대가 나올 확률
n = 5
for i in range(n+1):
    # 이항분포 Probability Mass Function
    prop = stats.binom.pmf(k=i, n=n, p=0.3)
    print("(X={0}) = {1:.3f}".format(i, prop))
# Out:
# (X=0) = 0.168
# (X=1) = 0.360
# (X=2) = 0.309
# (X=3) = 0.132
# (X=4) = 0.028
# (X=5) = 0.002

# %% [markdown]
# # P36 포아송

# %%
mu = 2
prop = stats.poisson.pmf(3, mu)
cdf_prop = stats.poisson.cdf(2, mu)
print("1분당 {0}번의 전화가 걸려올 확률: {1:.4f}".format(3, prop))
print("1분당 최대 {0}회 이하의 전화가 걸려올 확률: {1:.4f}".format(2, cdf_prop))
# Out:
# 1분당 3번의 전화가 걸려올 확률: 0.1804
# 1분당 최대 2회 이하의 전화가 걸려올 확률: 0.6767

# %%
'''
한 상점에는 평균 1시간에 2명씩 포아송분포로 손님이 도착한다.
이 때 10시에는 11시 사이에 다음이 발생할 확률을 구하시오.
1) 2명의 손님이 도착
2) 1명 이하의 손님이 도착
3) 3명 이상의 손님이 도착
'''

mu = 2
prop = stats.poisson.pmf(2, mu)
b_prop = stats.poisson.cdf(1, mu)
c_prop = stats.poisson.cdf(2, mu)
print("10시 11시 사이에 {0}명의 손님이 올 확률: {1:.4f}".format(2, prop))
print("10시 11시 사이에 {0}명 이하의 손님이 도착 확률: {1:.4f}".format(1, b_prop))
print("10시 11시 사이에 {0}명 이상의 손님이 도착 확률: {1:.4f}".format(3, 1-c_prop))
# Out:
# 10시 11시 사이에 2명의 손님이 올 확률: 0.2707
# 10시 11시 사이에 1명 이하의 손님이 도착 확률: 0.4060
# 10시 11시 사이에 3명 이상의 손님이 도착 확률: 0.3233

# %% [markdown]
# # P41

# %%
mycar = pd.read_csv('../mycars.csv')

# %%
mycar.head()
# Out:
#   manufacturer model  displacement   ...     highway_mileage  fuel    class
# 0         audi    a4           1.8   ...                  29     p  compact
# 1         audi    a4           1.8   ...                  29     p  compact
# 2         audi    a4           2.0   ...                  31     p  compact
# 3         audi    a4           2.0   ...                  30     p  compact
# 4         audi    a4           2.8   ...                  26     p  compact
#
# [5 rows x 11 columns]

# %%
df = mycar[['model','mpg']]

# %%
df.groupby('model').describe()
# Out:
#                          mpg                       ...
#                        count       mean       std  ...    50%    75%   max
# model                                              ...
# 4runner 4wd              6.0  15.166667  0.752773  ...   15.0  15.75  16.0
# a4                       7.0  18.857143  1.864454  ...   18.0  20.50  21.0
# a4 quattro               8.0  17.125000  1.807722  ...   17.0  18.25  20.0
# a6 quattro               3.0  16.000000  1.000000  ...   16.0  16.50  17.0
# altima                   6.0  20.666667  1.966384  ...   20.0  22.50  23.0
# c1500 suburban 2wd       5.0  12.800000  1.303840  ...   13.0  14.00  14.0
# camry                    7.0  19.857143  1.463850  ...   21.0  21.00  21.0
# camry solara             7.0  19.857143  1.772811  ...   21.0  21.00  22.0
# caravan 2wd             11.0  15.818182  1.834022  ...   16.0  17.00  18.0
# civic                    9.0  24.444444  1.943651  ...   24.0  25.00  28.0
# ...

# %% [markdown]
# # P42

# %%
df_a = mycar[['manufacturer','mpg']]

df_a.groupby('manufacturer').describe()
# Out:
#                mpg
#              count       mean       std   min   25%   50%    75%   max
# manufacturer
# audi          18.0  17.611111  1.974511  15.0  16.0  17.5  18.75  21.0
# chevrolet     19.0  15.000000  2.924988  11.0  13.5  15.0  16.50  22.0
# dodge         37.0  13.135135  2.485091   9.0  11.0  13.0  15.00  18.0
# ford          25.0  14.000000  1.914854  11.0  13.0  14.0  15.00  18.0
# honda          9.0  24.444444  1.943651  21.0  24.0  24.0  25.00  28.0
# hyundai       14.0  18.642857  1.499084  16.0  18.0  18.5  19.75  21.0
# jeep           8.0  13.500000  2.507133   9.0  12.5  14.0  15.00  17.0
# land rover     4.0  11.500000  0.577350  11.0  11.0  11.5  12.00  12.0
# lincoln        3.0  11.333333  0.577350  11.0  11.0  11.0  11.50  12.0
# mercury        4.0  13.250000  0.500000  13.0  13.0  13.0  13.25  14.0
# nissan        13.0  18.076923  3.426892  12.0  15.0  19.0  19.00  23.0
# pontiac        5.0  17.000000  1.000000  16.0  16.0  17.0  18.00  18.0
# ...

# %%
df_b = mycar[['automatic','mpg']]
df_b.groupby('automatic').describe()
# Out:
#              mpg
#            count       mean       std  min   25%   50%   75%   max
# automatic
# auto       157.0  15.968153  3.848777  9.0  13.0  16.0  18.0  29.0
# manual      77.0  18.675325  4.488118  9.0  15.0  18.0  21.0  35.0

# %%
ds_Exh_QC1 = pd.read_csv("../EXH_QC1.csv", engine='python')

# %%
data = ds_Exh_QC1.copy()

# %%
data.head()
# Out:
#      Flaws Period  Strength  Baking Time  Cabbage weight
# 0  Scratch    Day      37.6     0.798922             3.6
# 1  Scratch    Day      38.6     0.849020             2.9
# 2     Peel    Day      37.2     0.816163             2.8
# 3     Peel    Day      36.4     0.758266             2.6
# 4   Smudge    Day      38.6     0.815894             3.4

# %%
count = data['Flaws'].value_counts().sort_index()

# %%
cumcnt = np.cumsum(count)

# %%
percent = count / sum(count) * 100

# %%
cumpct = np.cumsum(percent)

# %%
count_data = pd.DataFrame({"Count":count,"CumCnt":cumcnt,"Percent":percent, "CumPct":cumpct})

# %%
# Column의 name(좌측상단 이름) 생성
count_data.columns.name = 'Flaws'

# %%
count_data
# Out:
# Flaws    Count  CumCnt  Percent  CumPct
# Other        6       6     15.0    15.0
# Peel        15      21     37.5    52.5
# Scratch     13      34     32.5    85.0
# Smudge       6      40     15.0   100.0

# %%
mycar.head()
# Out:
#   manufacturer model  displacement   ...     highway_mileage  fuel    class
# 0         audi    a4           1.8   ...                  29     p  compact
# 1         audi    a4           1.8   ...                  29     p  compact
# 2         audi    a4           2.0   ...                  31     p  compact
# 3         audi    a4           2.0   ...                  30     p  compact
# 4         audi    a4           2.8   ...                  26     p  compact
#
# [5 rows x 11 columns]

# %%
p45 = mycar[['model','mpg']]

# %%
count = p45['model'].value_counts().sort_index()

cumcnt = np.cumsum(count)

percent = count / sum(count) * 100

cumpct = np.cumsum(percent)

count_data = pd.DataFrame({"Count":count,"CumCnt":cumcnt,"Percent":percent, "CumPct":cumpct})

# %%
# Column의 name(좌측상단 이름) 생성
count_data.columns.name = 'model'

# %%
count_data['Percent'] = count_data['Percent'].map(lambda x : round(x,2))
count_data['CumPct'] = count_data['CumPct'].map(lambda x : round(x,2))

# %%
count_data
# Out:
# model                   Count  CumCnt  Percent  CumPct
# 4runner 4wd                 6       6     2.56    2.56
# a4                          7      13     2.99    5.56
# a4 quattro                  8      21     3.42    8.97
# a6 quattro                  3      24     1.28   10.26
# altima                      6      30     2.56   12.82
# c1500 suburban 2wd          5      35     2.14   14.96
# camry                       7      42     2.99   17.95
# camry solara                7      49     2.99   20.94
# caravan 2wd                11      60     4.70   25.64
# civic                       9      69     3.85   29.49
# corolla                     5      74     2.14   31.62
# corvette                    5      79     2.14   33.76
# dakota pickup 4wd           9      88     3.85   37.61
# durango 4wd                 7      95     2.99   40.60
# expedition 2wd              3      98     1.28   41.88
# explorer 4wd                6     104     2.56   44.44
# ...

# %% [markdown]
# # P59

# %%
ds_example = pd.read_csv('../EXH_QC.csv')

# %%
ds_example.head()
# Out:
#      Flaws Period  Strength  Baking Time  Cabbage weight
# 0  Scratch    Day      37.6     0.798922             3.6
# 1  Scratch    Day      38.6     0.849020             2.9
# 2     Peel    Day      37.2     0.816163             2.8
# 3     Peel    Day      36.4     0.758266             2.6
# 4   Smudge    Day      38.6     0.815894             3.4

# %%
df = ds_example[['Cabbage weight']].copy()

# %%
lower, upper = stats.norm.interval(0.95, loc = 2.7, scale = 0.397/np.sqrt(40))

# %%
print("신뢰구간 :({0},{1})".format(lower.round(2), upper.round(2)))
# Out:
# 신뢰구간 :(2.58,2.82)

# %%
lower, upper = stats.norm.interval(0.95, loc = df.mean(), scale = stats.sem(df))

# %%
print("신뢰구간 :({0},{1})".format(lower.round(2), upper.round(2)))
# Out:
# 신뢰구간 :([2.57],[2.82])

# %% [markdown]
# # 숙제 2

# %%
'''
새로운 품종의 감자 20 Box를 랜덤추출하여 무게를 측정할 결과가 다음과 같음
모표준편차는 3.8
신뢰구간 95%를 구하세요.
'''
values = [18,18,20,21,20,23,19,18,17,21,22,20,20,21,20,19,19,18,17,19]
mu = sum(values) / len(values)
lower, upper = stats.norm.interval(0.95, loc = mu, scale = 3.8/np.sqrt(20))
print("신뢰구간 :({0},{1})".format(lower.round(2), upper.round(2)))
# Out:
# 신뢰구간 :(17.83,21.17)

# %% [markdown]
# # P61

# %%
df = pd.DataFrame({'sample':[54.1,43.3,56.1,55.7,54.0,54.1,54.5,57.1,55.2,53.8,54.1,54.1,56.1,55.0,55.9,56.0,54.9,54.3,53.9,55.0]})

# %%
lower, upper = stats.t.interval(0.95, len(df)-1, loc = np.mean(df), scale = stats.sem(df))

# %%
print("신뢰구간:({0},{1})".format(lower.round(2), upper.round(2)))
# Out:
# 신뢰구간:([53.06],[55.66])

# %% [markdown]
# # P63 1-sample T Test

# %%
df = pd.DataFrame({'sample':[74.5,81.2,73.8,82.0,76.3,75.7,80.2,72.6,77.9,82.8]})
t_result = stats.ttest_1samp(df, 76.7)
t, p = t_result.statistic.round(3), t_result.pvalue.round(3)
print("1-Sample t-test")
print("t검정통계량:{}".format(t))
print("p-value:{}".format(p))
# Out:
# 1-Sample t-test
# t검정통계량:[0.864]
# p-value:[0.41]

# %% [markdown]
# # 숙제 3

# %%
data = [85.0, 79.0, 79.1,79.9,81.6,78.6,85.4,83.4,78.1,79.2]
mu = 76.7
s = 2.742

# %%
t_result = stats.ttest_1samp(data, mu)
t, p = t_result.statistic.round(3), t_result.pvalue.round(3)
print("1-Sample t-test")
print("t검정통계량:{}".format(t))
print("p-value:{}".format(p))
# Out:
# 1-Sample t-test
# t검정통계량:4.879
# p-value:0.001

# %% [markdown]
# # P 65

# %%
a = [6,5,5,4,6,7,6,4,5,6,4,5,5,6,4,8,6,5,6,7]
b = [7,5,7,8,7,8,8,5,7,6,5,5,6,6,5,7,9,7,7,8]
t_result = stats.ttest_ind(a, b)
t, p = t_result.statistic.round(3), t_result.pvalue.round(3)
print("2-Sample t-test")
print("t검정통계량 : {}".format(t))
print("p-value:{}".format(p))
# Out:
# 2-Sample t-test
# t검정통계량 : -3.122
# p-value:0.003
